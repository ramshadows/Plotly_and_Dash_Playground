# %%
import numpy as np
import pandas as pd
import plotly.offline as pyo
import plotly.graph_objs as go
import matplotlib.pyplot as plt




pd.options.display.max_columns = None
pd.options.display.max_rows = None

np.random.seed(42)

# %%
# create fake data:
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df
# Out:
#            A         B         C         D
# 0   0.805645  0.510557 -0.045260 -0.544695
# 1   0.549543 -1.421305 -0.642888 -0.522887
# 2   1.165794 -0.098127  0.306110 -0.635077
# 3  -0.653349  0.518963  0.811726  0.684167
# 4  -0.866878 -0.240168  0.283345  1.235821
# 5  -0.443755  0.749208 -0.629508 -1.102080
# 6  -1.739971 -0.982671  1.653324 -0.182053
# 7  -1.469062 -0.697545 -0.107518  0.369616
# 8  -1.917648  0.076516  0.092613 -0.314059
# 9   0.477747 -0.449702 -0.457417  1.261782
# 10  1.156615 -0.840074 -0.855471 -0.583128
# 11  1.104700 -0.150856 -0.013740 -0.733556
# 12 -0.342128 -1.259306 -0.534638 -0.444327
# 13  0.169011 -0.194337 -0.572247 -0.097494
# 14  0.010374  0.458217  0.570021 -0.036948
# 15 -0.856866 -0.959816  0.155624  0.137846
# 16 -0.737384  1.891253  0.660857  0.612883
# 17 -0.594270  0.158231 -0.552592  0.930731
# 18 -1.100422  1.108037  0.706716 -0.572477
# 19  0.710448  0.676306  0.538860 -0.077528
# 20 -0.223415  0.535685 -1.174197  1.423558
# 21 -1.111955 -0.159936 -0.252966 -0.399196
# 22 -0.551053  0.493820  0.735430  0.819325
# 23 -1.605837 -1.537010 -0.269006 -1.414707
# 24 -0.128791  0.462259 -0.271683 -0.050664
# 25  1.139168  0.145191 -0.033494 -1.141773
# 26 -0.358995 -1.358854  0.535560 -0.574227
# 27 -0.546851  1.478816  0.483147  1.735883
# 28  0.588512  0.123954 -1.005411 -1.734700
# 29  0.533253 -1.812785 -0.305054 -3.234171
# 30 -0.094494  1.087688 -0.242661 -0.332676
# 31  0.317991 -0.524292  0.556588 -1.044731
# 32 -0.247116 -0.197521 -0.416629 -0.758601
# 33 -0.570937 -0.919135 -0.821027 -1.917857
# 34  0.554116  1.207685 -0.836130 -0.833875
# 35 -2.927550  1.331098  0.295885 -0.528507
# 36 -0.311238 -0.336931  0.407389  0.663075
# 37 -0.545087 -1.134451 -0.440556 -0.542638
# 38 -2.044820 -1.676005 -0.451257 -1.938686
# 39 -0.583236  1.412298  1.517569 -0.038348
# 40 -0.224677 -1.185279 -0.648126 -0.635499
# 41 -0.715722  0.225340  2.475632  1.675442
# 42  0.225898  0.154773 -0.387171 -0.493965
# 43 -1.045092 -0.963358  0.031493  3.313472
# 44  1.059488  0.525583 -0.341969 -0.406882
# 45 -1.056954 -1.366375  1.143746  0.566967
# 46  0.860460 -0.452910 -0.332448  0.008706
# 47 -0.299553  0.913669 -1.212008  0.188171
# 48 -0.461256  1.893905 -0.733322  0.799270
# 49  0.271427 -0.526493 -0.526127  0.359990
# 50  0.449661 -2.046469  0.210260 -0.955512
# 51  0.355720 -0.597822 -0.401808  0.813261
# 52 -0.464189 -0.059196  0.679616 -0.437155
# 53 -0.697541 -0.222512 -0.045292 -0.513897
# 54 -1.496986  0.776018 -0.129494  0.464907
# 55  1.276782 -0.054220  1.391405  0.570174
# 56  0.515455 -0.438285 -0.785220  0.378633
# 57  0.911478 -0.060308 -0.625042 -1.976807
# 58 -3.513929  1.187901 -0.800513 -0.483909
# 59 -1.015792 -1.665361  0.475470  0.500633
# 60 -0.242410  1.562918 -1.245901 -0.855293
# 61  0.543019 -0.262587  1.078691  1.379040
# 62  0.646785 -0.910334  0.429540  0.252506
# 63  0.097643 -0.828991  0.680722  0.673107
# 64 -0.607234  0.925447  1.247101  0.369194
# 65 -0.163723 -0.168453  0.890814 -0.534670
# 66 -0.471373  0.135635 -1.028982  1.417004
# 67 -1.737999  0.585757 -2.899953 -0.287607
# 68  1.153606 -0.378760 -0.478104 -0.903817
# 69 -1.666103 -0.675353 -0.786318 -0.986011
# 70  1.425916 -0.813343  0.824397 -0.239267
# 71  0.539054 -2.267055  0.431492  0.385987
# 72 -0.175143 -2.009331 -0.480268  0.720688
# 73 -1.029177  0.301253 -0.182201  1.305912
# 74 -0.484788 -0.320912  0.581029 -0.751858
# 75 -1.320780 -0.806637 -0.608314 -0.400508
# 76 -0.756455  0.227773 -2.242898 -0.804937
# 77 -0.439365  0.924779 -1.015002 -1.099359
# 78  1.920724 -0.592158  0.736464 -0.119035
# 79  0.727871 -0.662504 -0.301835  0.226253
# 80  0.898057 -0.108424 -0.531311  0.091017
# 81 -0.338974  0.036559 -1.246206 -2.637994
# 82 -1.143763 -1.305417  0.456797  1.885411
# 83 -0.449916  0.921945  0.451050 -0.345084
# 84  1.901331 -0.615010  2.525114 -0.280710
# 85  0.208600 -0.761009  0.320382 -0.983503
# 86  0.217670  0.561782 -0.807227 -0.102577
# 87  0.429358  0.885964  0.518465  1.815283
# 88  0.140417 -1.505952 -0.882139  0.794910
# 89 -0.504643  0.937121 -0.556114  0.144356
# 90 -1.461372  0.566515 -0.827489 -0.952454
# 91 -2.215628 -1.993898  0.283204 -0.441958
# 92  0.549492  0.443387 -0.287681 -0.463249
# 93  1.204664  1.799260 -0.548356  0.664581
# 94  0.565386 -1.133605 -1.295425 -1.128239
# 95 -1.455151 -0.823383  0.725912 -1.361025
# 96  0.406088  0.340521  0.715066  0.699473
# 97  1.175315  0.633740 -0.488369 -0.262131
# 98 -0.090550 -1.956709  0.632633  2.355716
# 99 -1.229351  0.590172 -0.809954 -0.222022

# %%
df.plot()
plt.show()

# %%
pyo.plot([{
    'x': df.index,
    'y': df[col],
    'name': col
} for col in df.columns])
# Out:
# 'temp-plot.html'

# %% [markdown]
# # Plotly Scatter plots

# %%
random_x = np.random.randint(1, 101, 100)
random_y = np.random.randint(1, 101, 100)

# %%
data = [go.Scatter(x = random_x,
                   y = random_y,
                   mode = 'markers',
                  marker = dict(
                  size = 12,
                  color = 'rgb(51, 204, 153)',
                  symbol = 'pentagon',
                  line = {"width" : 2} ))]

# %%
pyo.plot(data, filename="scatter.html")
# Out:
# 'scatter.html'

# %% [markdown]
# ## Defining axis labels

# %%
layout = go.Layout(title = "My First Plot",
                   xaxis = {"title" : "X Axis Label"},
                   yaxis = dict(title="Y Axis Label"),
                  hovermode = "closest")

# %% [markdown]
# ## Then define the Figure and pass the Layout + Data

# %%
fig = go.Figure(data=data, layout=layout)

# %% [markdown]
# ## Now plot

# %%
pyo.plot(fig, filename="scatter.html")
# Out:
# 'scatter.html'
